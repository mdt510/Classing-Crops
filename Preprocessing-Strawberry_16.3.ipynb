# %% [markdown]
# **Pre-Processing & Training Data Development - 16.3**

# %%
import pandas as pd
from PIL import Image

# %% [markdown]
# **LOAD** the data

# %%
img = Image.open('/content/drive/MyDrive/Strawberry_Grading/Strawberry Images/10_100.jpg')  #open image

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7FA024033F90>

# %% [markdown]
# **ROTATE** img by 45' cc

# %%
rotated = img.rotate(45)  # Rotate it by 45 degrees
rotated
# Rotate it by 90 degrees
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA02409DE90>

# %% [markdown]
# **ROTATE** img by 90' cc

# %%
transposed  = img.transpose(Image.ROTATE_90)  # Rotate it by 90 degrees
transposed
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA0257B5290>

# %% [markdown]
# **CROP** img

# %%
# Size of the image in pixels (size of orginal image) 
width, height = img.size 

# Setting the points for cropped image 
left = 5
top = height / 4
right = 164
bottom = 3 * height / 4
  
# Cropped image of above dimension 
# (It will not change orginal image) 
im1 = img.crop((left, top, right, bottom))
im1
# Out:
# <PIL.Image.Image image mode=RGB size=159x50 at 0x7FA02406BA50>
